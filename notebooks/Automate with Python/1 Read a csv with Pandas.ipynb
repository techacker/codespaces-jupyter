# %% [markdown]
# # Automate with Python Course on YouTube
# ##### https://www.youtube.com/watch?v=PXMJ6FS7llk
# ##### Target Website - https://www.football-data.co.uk/data.php

# %%
import pandas as pd

# %% [markdown]
# #### 1. Read a .csv from a URL with Pandas

# %%
# Reading 1 csv file from website
# Getting 24
df24Prem = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/E0.csv')
df24Prem
# Out:
#     Div        Date   Time       HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  11/08/2023  20:00        Burnley       Man City     0     3   A
# 1    E0  12/08/2023  12:30        Arsenal  Nott'm Forest     2     1   H
# 2    E0  12/08/2023  15:00    Bournemouth       West Ham     1     1   D
# 3    E0  12/08/2023  15:00       Brighton          Luton     4     1   H
# 4    E0  12/08/2023  15:00        Everton         Fulham     0     1   A
# ..   ..         ...    ...            ...            ...   ...   ...  ..
# 193  E0  30/12/2023  17:30  Nott'm Forest     Man United     2     1   H
# 194  E0  31/12/2023  14:00         Fulham        Arsenal     2     1   H
# 195  E0  31/12/2023  14:00      Tottenham    Bournemouth     3     1   H
# 196  E0  01/01/2024  20:00      Liverpool      Newcastle     4     2   H
# 197  E0  02/01/2024  19:30       West Ham       Brighton     0     0   D
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# ...

# %%
# Rename Columns
df24Prem.rename(columns={'FTHG': 'HomeGoals',
                         'FTAG': 'AwayGoals'}, inplace=True)
df24Prem
# Out:
#     Div        Date   Time       HomeTeam       AwayTeam  HomeGoals  \
# 0    E0  11/08/2023  20:00        Burnley       Man City          0
# 1    E0  12/08/2023  12:30        Arsenal  Nott'm Forest          2
# 2    E0  12/08/2023  15:00    Bournemouth       West Ham          1
# 3    E0  12/08/2023  15:00       Brighton          Luton          4
# 4    E0  12/08/2023  15:00        Everton         Fulham          0
# ..   ..         ...    ...            ...            ...        ...
# 193  E0  30/12/2023  17:30  Nott'm Forest     Man United          2
# 194  E0  31/12/2023  14:00         Fulham        Arsenal          2
# 195  E0  31/12/2023  14:00      Tottenham    Bournemouth          3
# 196  E0  01/01/2024  20:00      Liverpool      Newcastle          4
# 197  E0  02/01/2024  19:30       West Ham       Brighton          0
#
#      AwayGoals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  \
# ...
